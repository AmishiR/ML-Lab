# %% [markdown]
# <a href="https://colab.research.google.com/github/AmishiR/ML-Lab/blob/main/LAB2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder,OneHotEncoder,StandardScaler,MinMaxScaler
from sklearn.feature_selection import SelectKBest,f_classif,RFE

# %%
df=pd.read_csv("/content/titanic (3).csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Gender', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass                 Name Gender  \
# count    891.000000  891.000000  891.000000                  891    891
# unique          NaN         NaN         NaN                  891      2
# top             NaN         NaN         NaN  Dooley, Mr. Patrick   male
# freq            NaN         NaN         NaN                    1    577
# mean     446.000000    0.383838    2.308642                  NaN    NaN
# std      257.353842    0.486592    0.836071                  NaN    NaN
# min        1.000000    0.000000    1.000000                  NaN    NaN
# 25%      223.500000    0.000000    2.000000                  NaN    NaN
# 50%      446.000000    0.000000    3.000000                  NaN    NaN
# 75%      668.500000    1.000000    3.000000                  NaN    NaN
# max      891.000000    1.000000    3.000000                  NaN    NaN
#
#                Age       SibSp       Parch  Ticket        Fare Cabin Embarked
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.fillna(0)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.notnull()
# Out:
#      PassengerId  Survived  Pclass  Name  Gender    Age  SibSp  Parch  Ticket  \
# 0           True      True    True  True    True   True   True   True    True
# 1           True      True    True  True    True   True   True   True    True
# 2           True      True    True  True    True   True   True   True    True
# 3           True      True    True  True    True   True   True   True    True
# 4           True      True    True  True    True   True   True   True    True
# ..           ...       ...     ...   ...     ...    ...    ...    ...     ...
# 886         True      True    True  True    True   True   True   True    True
# 887         True      True    True  True    True   True   True   True    True
# 888         True      True    True  True    True  False   True   True    True
# 889         True      True    True  True    True   True   True   True    True
# 890         True      True    True  True    True   True   True   True    True
#
#      Fare  Cabin  Embarked
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isna()
# Out:
#      PassengerId  Survived  Pclass   Name  Gender    Age  SibSp  Parch  \
# 0          False     False   False  False   False  False  False  False
# 1          False     False   False  False   False  False  False  False
# 2          False     False   False  False   False  False  False  False
# 3          False     False   False  False   False  False  False  False
# 4          False     False   False  False   False  False  False  False
# ..           ...       ...     ...    ...     ...    ...    ...    ...
# 886        False     False   False  False   False  False  False  False
# 887        False     False   False  False   False  False  False  False
# 888        False     False   False  False   False   True  False  False
# 889        False     False   False  False   False  False  False  False
# 890        False     False   False  False   False  False  False  False
#
#      Ticket   Fare  Cabin  Embarked
# 0     False  False   True     False
# 1     False  False  False     False
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Gender'].value_counts()
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
print(df['Age'].isnull().sum())
# Out:
# 177

# %%
df[df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df[df['Embarked'].isnull()]  #index of rows where embarked inof is not mentioned
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#      Gender   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# ================================
# 2. Handling Missing Data
# ================================

# %%
num_imputer = SimpleImputer(strategy='mean')
num_imputer.fit(df[['Age']])
df['Age'] = num_imputer.transform(df[['Age']])

#df['Age] = num_imputer.fit_transform(df[['Age']])

# %%
print(df['Age'].isnull().sum())
# Out:
# 0

# %%
#For categorical data
cat_imputer = SimpleImputer(strategy='most_frequent')
df['Embarked'] = df['Embarked'].astype('category')
df['Embarked'] = cat_imputer.fit_transform(df[['Embarked']]).ravel()

# %%
df['Embarked'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()  #to drop duplicates
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
Q1 =df['Fare'].quantile(0.25)
Q2 =df['Fare'].quantile(0.50)
Q3 =df['Fare'].quantile(0.75)
IQR =Q3-Q1

# %%
outliers=df[(df['Fare'] < (Q1-1.5 *IQR)) | (df['Fare'] >  (Q3+1.5 *IQR)) ]
print("Outliers in fare :", outliers.shape)
# Out:
# Outliers in fare : (116, 12)

# %%
display(outliers)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 27            28         0       1
# 31            32         1       1
# 34            35         0       1
# 52            53         1       1
# ..           ...       ...     ...
# 846          847         0       3
# 849          850         1       1
# 856          857         1       1
# 863          864         0       3
# 879          880         1       1
#
#                                                   Name  Gender        Age  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 27                      Fortune, Mr. Charles Alexander    male  19.000000
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female  29.699118
# 34                             Meyer, Mr. Edgar Joseph    male  28.000000
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.000000
# ..                                                 ...     ...        ...
# ...

# %%
DF1 =df[(df['Fare'] > (Q1-1.5 *IQR)) & (df['Fare'] <  (Q3+1.5 *IQR)) ]
DF1.shape
# Out:
# (775, 12)

# %%
DF2 = df.drop(outliers.index)
display(DF2.shape)
# Out:
# (775, 12)

# %%
# For nominal feature we use One Hot Encoding
# For ordinal feature we use Label Encdoing

# %%
#Label Encoding
df['Gender_encoded']=LabelEncoder().fit_transform(df['Gender'])

# %%
df['Gender_encoded'].value_counts()
# Out:
# Gender_encoded
# 1    577
# 0    314
# Name: count, dtype: int64

# %%
#DF1=OneHotEncoder().fit_transform(df[['Embarked']]).toarray()
#DF1

# %%
#OneHot Encoding
df=pd.get_dummies(df, columns=['Embarked'],drop_first=False)

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name  Gender        Age  \
# 0                            Braund, Mr. Owen Harris    male  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                             Heikkinen, Miss. Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# 5                                   Moran, Mr. James    male  29.699118
# 6                            McCarthy, Mr. Timothy J    male  54.000000
# ...

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name  Gender        Age  \
# 0                            Braund, Mr. Owen Harris    male  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                             Heikkinen, Miss. Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# 5                                   Moran, Mr. James    male  29.699118
# 6                            McCarthy, Mr. Timothy J    male  54.000000
# ...

# %%
# ================================
# 6. Feature Scaling
# ================================

# %%
df['Age_scaled']=StandardScaler().fit_transform(df[['Age']])  #fit calculates average and transform implies the formula
df['Fare_scaled']=StandardScaler().fit_transform(df[['Fare']])

# %%
print(df['Age_scaled'].mean())
print(df['Fare_scaled'].mean())
# Out:
# 2.2329064647904385e-16
# 3.987332972840069e-18

# %%
print(df['Age_scaled'].std())
print(df['Fare_scaled'].std())
# Out:
# 1.0005616400330466
# 1.0005616400330462

# %%
#Min Max Scaling
df['Age_scaled_1']=MinMaxScaler().fit_transform(df[['Age']])  #fit calculates min and max and transform implies the formula
df['Fare_scaled_1']=MinMaxScaler().fit_transform(df[['Fare']])

# %%
print(df['Age_scaled_1'].mean())
print(df['Fare_scaled_1'].mean())
# Out:
# 0.3679205534940792
# 0.06285842768394742

# %%
print(df['Age_scaled_1'].std())
print(df['Fare_scaled_1'].std())
# Out:
# 0.16338295081682433
# 0.09699511290237

# %%
#Standardization / Feature normalization
Scaler=StandardScaler().fit(df[['Age']])

# %%
# ================================
# 7. Feature Engineering
# ================================

# %%
df['FamilySize']=df['SibSp']+df['Parch']+1 #Generatinf new feature(column) from exiisting one
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin  Gender_encoded  Embarked_C  \
# 0      0         A/5 21171   7.2500   NaN               1       False
# 1      0          PC 17599  71.2833   C85               0        True
# 2      0  STON/O2. 3101282   7.9250   NaN               0       False
# ...

# %%
# ================================
# 8. Feature Selection
# ================================

# %%
X=df[['Age','Fare','FamilySize']]
y=df['Survived']

# %%
#bestfeatures=SelectKBest(score_func=f_classif,k=2)
#Fit = bestfeatures().fit(X, y)
#print("Scores from feature",Fit.scores_)

# %%
X_selected=Fit.transform(X)
X_selected.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-129-336105180.py in <cell line: 0>()
# ----> 1 X_selected=Fit.transform(X)
#       2 X_selected.shape
#
# NameError: name 'Fit' is not defined
